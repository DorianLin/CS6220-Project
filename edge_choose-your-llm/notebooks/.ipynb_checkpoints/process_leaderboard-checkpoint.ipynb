# %%
# import packages
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
# data cleaning
data = pd.read_csv('../Scraper/open-llm-leaderboard.csv') # read the full leaderboard

# %%
data.loc[data['model_name_for_query']=='microsoft/phi-1_5', '#Params (B)']
# Out:
# 1025    0.0
# Name: #Params (B), dtype: float64

# %%
# fixing a mistake for microsoft's phi-1_5
data.loc[data['Model']=='microsoft/phi-1_5', '#Params (B)'] = 1.3
# fixing a mistake for roneneldan/TinyStories-1M
data.loc[data['Model']=='roneneldan/TinyStories-1M', '#Params (B)'] = 0.001
# removing models with size 0
data = data.loc[data['#Params (B)'] != 0]

# %%
data.loc[data['Model'] == "AA051610/T1B"]
# Out:
#      T         Model  Average ⬆️    ARC  HellaSwag   MMLU  TruthfulQA  \
# 535  🔶  AA051610/T1B       60.74  56.14      79.78  60.01       47.02
#
#            Type       Precision Hub License  #Params (B)  Hub ❤️  \
# 535  fine-tuned  torch.bfloat16           ?          1.0     0.0
#
#                                     Model Sha
# 535  6f3664328e9f07a6578ccb0c5713b747cc0549d5

# %%
from gradio_client import Client
import json
client = Client("https://felixz-open-llm-leaderboard.hf.space/")

json_data = client.predict("","", api_name='/predict')

with open(json_data, 'r') as file:
    file_data = file.read()

# Load the JSON data
data = json.loads(file_data)

# Get the headers and the data
headers = data['headers']
data = data['data']
# Out:
# Loaded as API: https://felixz-open-llm-leaderboard.hf.space/ ✔

# %%
# Verify that each sub-array in `data` is the same length as `headers`
consistent_data = all(len(row) == len(headers) for row in data)

# Process if the data is consistent
if consistent_data:
    # Stack the data and convert it to a NumPy array
    numpy_array = np.column_stack(data)
else:
    numpy_array = None
    print("Data inconsistency detected: The length of each sub-array in 'data' must match the number of 'headers'.")

# Use numpy_array as needed
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 5
#       2 dtypes = [(h, 'U100') for h in headers]  # 'U100' is a data type for strings with max 100 characters
#       4 # Create the structured NumPy array
# ----> 5 structured_data = np.array(data, dtype=dtypes)
#       7 # Example of accessing data: Print the 'Model' column
#       8 print(structured_data['Model'])
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (1618, 18) + inhomogeneous part.

# %%
headers
# Out:
# ['T',
#  'Model',
#  'Average ⬆️',
#  'ARC',
#  'HellaSwag',
#  'MMLU',
#  'TruthfulQA',
#  'Winogrande',
#  'GSM8K',
#  'DROP',
#  'Type',
#  'Precision',
#  'Hub License',
#  '#Params (B)',
#  'Hub ❤️',
#  'Available on the hub',
#  'Model sha',
#  'model_name_for_query']

# %%
data
# Out:
# [['🟢',
#   '<a target="_blank" href="https://huggingface.co/01-ai/Yi-34B" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">01-ai/Yi-34B</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_01-ai__Yi-34B" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   68.68,
#   64.59,
#   85.69,
#   76.35,
#   56.23,
#   83.03,
#   50.64,
#   64.2,
#   'pretrained',
#   'torch.bfloat16',
#   'custom',
#   34.0,
#   15.0,
#   True,
#   'cd8d59de87ea11c6453ee287ac82e5523f08c8ec',
#   '01-ai/Yi-34B'],
#  ['⭕',
#   '<a target="_blank" href="https://huggingface.co/MayaPH/GodziLLa2-70B" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">MayaPH/GodziLLa2-70B</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_MayaPH__GodziLLa2-70B" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   67.01,
#   71.42,
#   87.53,
#   69.88,
#   61.54,
#   83.19,
#   43.21,
#   52.31,
#   'instruction-tuned',
#   'torch.float16',
#   'llama2',
#   68.98,
#   17.0,
#   True,
#   '7b78087db07eec97f7b461d10758ece76d685543',
#   'MayaPH/GodziLLa2-70B'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/sequelbox/StellarBright" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">sequelbox/StellarBright</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_sequelbox__StellarBright" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   66.98,
#   72.95,
#   87.82,
#   71.17,
#   64.46,
#   83.27,
#   39.5,
#   49.66,
#   'fine-tuned',
#   'torch.float16',
#   'llama2',
#   69.24,
#   8.0,
#   True,
#   '43efad8bfdb47139934e810906c1e59c25b5e269',
#   'sequelbox/StellarBright'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/garage-bAInd/Platypus2-70B-instruct" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">garage-bAInd/Platypus2-70B-instruct</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_garage-bAInd__Platypus2-70B-instruct" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   66.89,
#   71.84,
#   87.94,
#   70.48,
#   62.26,
#   82.72,
#   40.56,
#   52.41,
#   'fine-tuned',
#   'torch.float16',
#   'cc-by-nc-4.0',
#   68.72,
#   148.0,
#   True,
#   'a66378c15f89756215ccc64572ba69b161173703',
#   'garage-bAInd/Platypus2-70B-instruct'],
#  ['⭕',
#   '<a target="_blank" href="https://huggingface.co/upstage/SOLAR-0-70b-16bit" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">upstage/SOLAR-0-70b-16bit</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_upstage__SOLAR-0-70b-16bit" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   66.88,
#   71.08,
#   87.89,
#   70.58,
#   62.25,
#   83.58,
#   45.26,
#   47.49,
#   'instruction-tuned',
#   'torch.float16',
#   '?',
#   68.72,
#   214.0,
#   True,
#   '5f9c77b2c0397cf83d2f97740483f107c7109e8c',
#   'upstage/SOLAR-0-70b-16bit'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/Sao10K/Euryale-1.3-L2-70B" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">Sao10K/Euryale-1.3-L2-70B</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_Sao10K__Euryale-1.3-L2-70B" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   66.58,
#   70.82,
#   87.92,
#   70.39,
#   59.85,
#   82.79,
#   34.19,
#   60.1,
#   'fine-tuned',
#   'torch.float16',
#   'llama2',
#   68.72,
#   4.0,
#   True,
#   '6e3ce78eb5346bf3a5ee88cd60c25dc0d73de639',
#   'Sao10K/Euryale-1.3-L2-70B'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/psmathur/model_101" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">psmathur/model_101</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_psmathur__model_101" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   66.55,
#   68.69,
#   86.42,
#   69.92,
#   58.85,
#   82.08,
#   44.81,
#   55.1,
#   'fine-tuned',
#   'torch.float16',
#   '?',
#   68.72,
#   0.0,
#   True,
#   '884c53a64a3c5faf7b0706d36a587ca1532ed8f5',
#   'psmathur/model_101'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/OpenBuddy/openbuddy-llama2-70b-v10.1-bf16" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">OpenBuddy/openbuddy-llama2-70b-v10.1-bf16</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_OpenBuddy__openbuddy-llama2-70b-v10.1-bf16" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   66.47,
#   61.86,
#   83.13,
#   67.41,
#   56.18,
#   80.11,
#   60.27,
#   56.3,
#   'fine-tuned',
#   'torch.bfloat16',
#   '?',
#   68.76,
#   41.0,
#   True,
#   'a6ee90d262ac729f90ed8de97127766df070074c',
#   'OpenBuddy/openbuddy-llama2-70b-v10.1-bf16'],
#  ['⭕',
#   '<a target="_blank" href="https://huggingface.co/budecosystem/genz-70b" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">budecosystem/genz-70b</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_budecosystem__genz-70b" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   66.34,
#   71.42,
#   87.99,
#   70.78,
#   62.66,
#   83.5,
#   33.74,
#   54.28,
#   'instruction-tuned',
#   'torch.float16',
#   '?',
#   68.72,
#   26.0,
#   True,
#   '32110b4f33e5e80073ca1f47638482fdc0e19297',
#   'budecosystem/genz-70b'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/upstage/Llama-2-70b-instruct" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">upstage/Llama-2-70b-instruct</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_upstage__Llama-2-70b-instruct" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   66.1,
#   70.9,
#   87.48,
#   69.8,
#   60.97,
#   82.87,
#   32.22,
#   58.42,
#   'fine-tuned',
#   'torch.float16',
#   '?',
#   68.72,
#   53.0,
#   True,
#   '8469429924dc2e1a9394b8095753985668a4052e',
#   'upstage/Llama-2-70b-instruct'],
#  ['⭕',
#   '<a target="_blank" href="https://huggingface.co/ehartford/Samantha-1.11-70b" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">ehartford/Samantha-1.11-70b</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_ehartford__Samantha-1.11-70b" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   65.9,
#   70.05,
#   87.55,
#   67.82,
#   65.02,
#   83.27,
#   29.95,
#   57.68,
#   'instruction-tuned',
#   'torch.float16',
#   'llama2',
#   68.72,
#   30.0,
#   True,
#   '49e5b5ee0bed2864f0b38ba8bf9e01ccc5e0ba5f',
#   'ehartford/Samantha-1.11-70b'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/ICBU-NPU/FashionGPT-70B-V1.1" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">ICBU-NPU/FashionGPT-70B-V1.1</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_ICBU-NPU__FashionGPT-70B-V1.1" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   65.88,
#   71.76,
#   88.2,
#   70.99,
#   65.26,
#   82.64,
#   41.47,
#   40.81,
#   'fine-tuned',
#   'torch.float16',
#   'llama2',
#   68.72,
#   38.0,
#   True,
#   '05941a3eaacff0dead79b09d2175b5d7b98c525b',
#   'ICBU-NPU/FashionGPT-70B-V1.1'],
#  ['⭕',
#   '<a target="_blank" href="https://huggingface.co/chargoddard/MelangeB-70b" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">chargoddard/MelangeB-70b</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_chargoddard__MelangeB-70b" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   65.8,
#   71.67,
#   87.5,
#   70.03,
#   59.36,
#   83.5,
#   30.63,
#   57.92,
#   'instruction-tuned',
#   'torch.float16',
#   '?',
#   68.98,
#   0.0,
#   True,
#   '08239fb1e30b1e42b14370f23e942bc51e76027c',
#   'chargoddard/MelangeB-70b'],
#  ['⭕',
#   '<a target="_blank" href="https://huggingface.co/ehartford/Samantha-1.1-70b" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">ehartford/Samantha-1.1-70b</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_ehartford__Samantha-1.1-70b" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   65.74,
#   68.77,
#   87.46,
#   68.6,
#   64.85,
#   83.27,
#   31.61,
#   55.59,
#   'instruction-tuned',
#   'torch.float16',
#   'llama2',
#   68.72,
#   4.0,
#   True,
#   'a3819d186f5b4d52ced7ddeb7fa16bf66e8a2ea7',
#   'ehartford/Samantha-1.1-70b'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/AIDC-ai-business/Marcoroni-70B-v1" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">AIDC-ai-business/Marcoroni-70B-v1</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_AIDC-ai-business__Marcoroni-70B-v1" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   65.52,
#   73.55,
#   87.62,
#   70.67,
#   64.41,
#   83.43,
#   33.28,
#   45.65,
#   'fine-tuned',
#   'torch.bfloat16',
#   'cc-by-nc-4.0',
#   68.72,
#   16.0,
#   True,
#   '55a30d29db194832c0b5de1392a6598a63582144',
#   'AIDC-ai-business/Marcoroni-70B-v1'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/fangloveskari/Platypus_QLoRA_LLaMA_70b" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">fangloveskari/Platypus_QLoRA_LLaMA_70b</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_fangloveskari__Platypus_QLoRA_LLaMA_70b" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   65.41,
#   72.1,
#   87.46,
#   71.02,
#   61.18,
#   82.87,
#   30.78,
#   52.45,
#   'fine-tuned',
#   'torch.float16',
#   'llama2',
#   68.72,
#   3.0,
#   True,
#   'b9b8560832276f60ba6bf37ac913b230a85ac19b',
#   'fangloveskari/Platypus_QLoRA_LLaMA_70b'],
#  ['⭕',
#   '<a target="_blank" href="https://huggingface.co/v2ray/LLaMA-2-Wizard-70B-QLoRA" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">v2ray/LLaMA-2-Wizard-70B-QLoRA</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_v2ray__LLaMA-2-Wizard-70B-QLoRA" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   65.4,
#   67.58,
#   87.52,
#   69.11,
#   61.79,
#   82.32,
#   30.48,
#   59.03,
#   'instruction-tuned',
#   'torch.float16',
#   'llama2',
#   70.0,
#   2.0,
#   False,
#   '4bff676fe29f56d31961794c062aebc36312446e',
#   'v2ray/LLaMA-2-Wizard-70B-QLoRA'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/TigerResearch/tigerbot-70b-chat" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">TigerResearch/tigerbot-70b-chat</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_TigerResearch__tigerbot-70b-chat" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   65.32,
#   76.79,
#   87.76,
#   66.35,
#   55.09,
#   77.58,
#   45.64,
#   47.99,
#   'fine-tuned',
#   'torch.float16',
#   'apache-2.0',
#   68.95,
#   6.0,
#   False,
#   '7e506c4a056821e5d151a0e46572cd74d04194be',
#   'TigerResearch/tigerbot-70b-chat'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/TigerResearch/tigerbot-70b-chat" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">TigerResearch/tigerbot-70b-chat</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_TigerResearch__tigerbot-70b-chat" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   65.24,
#   76.79,
#   87.83,
#   66.08,
#   55.1,
#   77.9,
#   44.96,
#   48.02,
#   'fine-tuned',
#   'torch.bfloat16',
#   'apache-2.0',
#   68.95,
#   6.0,
#   False,
#   '7e506c4a056821e5d151a0e46572cd74d04194be',
#   'TigerResearch/tigerbot-70b-chat'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/psmathur/model_009" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">psmathur/model_009</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_psmathur__model_009" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   65.03,
#   71.59,
#   87.7,
#   69.43,
#   60.72,
#   82.32,
#   39.42,
#   44.01,
#   'fine-tuned',
#   'torch.float16',
#   'llama2',
#   68.72,
#   1.0,
#   True,
#   '5020869e6394b1ac039bf80a0a1d2bed6be6707e',
#   'psmathur/model_009'],
#  ['⭕',
#   '<a target="_blank" href="https://huggingface.co/jondurbin/airoboros-l2-70b-2.2.1" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">jondurbin/airoboros-l2-70b-2.2.1</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_jondurbin__airoboros-l2-70b-2.2.1" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   65.01,
#   69.71,
#   87.95,
#   69.79,
#   59.49,
#   82.95,
#   44.88,
#   40.27,
#   'instruction-tuned',
#   'torch.bfloat16',
#   'llama2',
#   68.72,
#   6.0,
#   True,
#   'eadc78a4a9e173bccdca7dc8d12a34e80317c66c',
#   'jondurbin/airoboros-l2-70b-2.2.1'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/stabilityai/StableBeluga2" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">stabilityai/StableBeluga2</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_stabilityai__StableBeluga2" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   64.97,
#   71.08,
#   86.37,
#   68.79,
#   59.44,
#   82.95,
#   35.86,
#   50.28,
#   'fine-tuned',
#   'torch.float16',
#   '?',
#   68.72,
#   836.0,
#   True,
#   'e4944caa6ece819413b140b8dcecea79fe7e22cf',
#   'stabilityai/StableBeluga2'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/psmathur/orca_mini_v3_70b" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">psmathur/orca_mini_v3_70b</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_psmathur__orca_mini_v3_70b" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   64.9,
#   71.25,
#   87.85,
#   70.18,
#   61.27,
#   82.72,
#   40.86,
#   40.17,
#   'fine-tuned',
#   'torch.float16',
#   'other',
#   68.72,
#   16.0,
#   True,
#   'c1d4f997f8ed685a6efc72229523b2e56fd0774b',
#   'psmathur/orca_mini_v3_70b'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/psmathur/model_51" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">psmathur/model_51</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_psmathur__model_51" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   64.88,
#   68.43,
#   86.71,
#   69.31,
#   57.18,
#   81.77,
#   32.37,
#   58.43,
#   'fine-tuned',
#   'torch.float16',
#   'llama2',
#   68.72,
#   1.0,
#   True,
#   '9542702011bf4d282f4b0f0bd79229f5822b6313',
#   'psmathur/model_51'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/v2ray/LLaMA-2-Jannie-70B-QLoRA" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">v2ray/LLaMA-2-Jannie-70B-QLoRA</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_v2ray__LLaMA-2-Jannie-70B-QLoRA" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   64.76,
#   68.94,
#   86.9,
#   69.37,
#   53.67,
#   82.95,
#   31.77,
#   59.75,
#   'fine-tuned',
#   'torch.float16',
#   'mit',
#   70.0,
#   14.0,
#   False,
#   'e552ddca841a2b86e36bbe5f99840afedfdbcd14',
#   'v2ray/LLaMA-2-Jannie-70B-QLoRA'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/fangloveskari/ORCA_LLaMA_70B_QLoRA" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">fangloveskari/ORCA_LLaMA_70B_QLoRA</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_fangloveskari__ORCA_LLaMA_70B_QLoRA" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   64.67,
#   72.27,
#   87.74,
#   70.23,
#   63.37,
#   83.66,
#   28.35,
#   47.04,
#   'fine-tuned',
#   'torch.float16',
#   'llama2',
#   68.72,
#   49.0,
#   True,
#   'ef9b04ef02ccc4d96f1181467da92bb6b5baf835',
#   'fangloveskari/ORCA_LLaMA_70B_QLoRA'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/migtissera/Synthia-70B-v1.2b" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">migtissera/Synthia-70B-v1.2b</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_migtissera__Synthia-70B-v1.2b" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   64.63,
#   68.77,
#   87.57,
#   68.81,
#   57.69,
#   83.9,
#   35.25,
#   50.41,
#   'fine-tuned',
#   'torch.float16',
#   'llama2',
#   68.72,
#   17.0,
#   True,
#   '7b687d6e4101b8bb8cc4062f8a318d639098a55d',
#   'migtissera/Synthia-70B-v1.2b'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/OpenBuddy/openbuddy-falcon-180b-v13-preview0" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">OpenBuddy/openbuddy-falcon-180b-v13-preview0</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_OpenBuddy__openbuddy-falcon-180b-v13-preview0" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   64.3,
#   65.1,
#   86.19,
#   64.6,
#   54.97,
#   82.64,
#   41.62,
#   54.98,
#   'fine-tuned',
#   '8bit',
#   '?',
#   178.64,
#   0.0,
#   True,
#   '7d7b93ffd67d1b0c39f3503050dbbcc951948120',
#   'OpenBuddy/openbuddy-falcon-180b-v13-preview0'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/garage-bAInd/Camel-Platypus2-70B" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">garage-bAInd/Camel-Platypus2-70B</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_garage-bAInd__Camel-Platypus2-70B" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   64.23,
#   71.08,
#   87.6,
#   70.04,
#   58.09,
#   83.82,
#   22.9,
#   56.1,
#   'fine-tuned',
#   'torch.float16',
#   'cc-by-nc-4.0',
#   68.72,
#   12.0,
#   True,
#   'b9f8de09ab860ee8ba570db7227c5444020ea056',
#   'garage-bAInd/Camel-Platypus2-70B'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/garage-bAInd/Platypus2-70B" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">garage-bAInd/Platypus2-70B</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_garage-bAInd__Platypus2-70B" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   64.16,
#   70.65,
#   87.15,
#   70.08,
#   52.37,
#   84.37,
#   33.06,
#   51.41,
#   'fine-tuned',
#   'torch.float16',
#   'cc-by-nc-sa-4.0',
#   68.72,
#   19.0,
#   True,
#   '16b6583ad58313331f86be18e531ab03f1857695',
#   'garage-bAInd/Platypus2-70B'],
#  ['?',
#   '<a target="_blank" href="https://huggingface.co/liuxiang886/llama2-70B-qlora-gpt4" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">liuxiang886/llama2-70B-qlora-gpt4</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_liuxiang886__llama2-70B-qlora-gpt4" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   64.13,
#   70.31,
#   86.39,
#   69.29,
#   54.02,
#   82.87,
#   28.89,
#   57.15,
#   '',
#   'torch.float16',
#   '?',
#   68.72,
#   0.0,
#   True,
#   '08115ee077953e9c01c6a40f5086def3ecf9f5f0',
#   'liuxiang886/llama2-70B-qlora-gpt4'],
#  ['⭕',
#   '<a target="_blank" href="https://huggingface.co/garage-bAInd/Camel-Platypus2-70B" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">garage-bAInd/Camel-Platypus2-70B</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_garage-bAInd__Camel-Platypus2-70B" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   64.05,
#   70.14,
#   87.71,
#   69.83,
#   57.77,
#   82.95,
#   23.96,
#   55.97,
#   'instruction-tuned',
#   '8bit',
#   'cc-by-nc-4.0',
#   68.72,
#   12.0,
#   True,
#   '6f958a1063fe1e6075f6e379fae621ff5a1d98c6',
#   'garage-bAInd/Camel-Platypus2-70B'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/s1ghhh/medllama-2-70b-qlora-1.1" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">s1ghhh/medllama-2-70b-qlora-1.1</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_s1ghhh__medllama-2-70b-qlora-1.1" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   63.58,
#   69.03,
#   87.17,
#   71.04,
#   52.41,
#   84.21,
#   32.07,
#   49.1,
#   'fine-tuned',
#   'torch.float16',
#   'llama2',
#   70.0,
#   1.0,
#   False,
#   'd55e05e9d67418c639933c85a5b9d17c6f531a92',
#   's1ghhh/medllama-2-70b-qlora-1.1'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/migtissera/Synthia-70B-v1.2" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">migtissera/Synthia-70B-v1.2</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_migtissera__Synthia-70B-v1.2" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   63.41,
#   70.48,
#   86.98,
#   70.13,
#   58.64,
#   83.27,
#   31.92,
#   42.42,
#   'fine-tuned',
#   'torch.float16',
#   'llama2',
#   68.72,
#   16.0,
#   True,
#   '9b92ee1093b125035ba1649dca6f4ceb9d86a656',
#   'migtissera/Synthia-70B-v1.2'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/psmathur/model_007" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">psmathur/model_007</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_psmathur__model_007" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   63.2,
#   71.08,
#   87.65,
#   69.04,
#   63.12,
#   83.35,
#   37.15,
#   31.05,
#   'fine-tuned',
#   'torch.float16',
#   'llama2',
#   68.72,
#   19.0,
#   True,
#   '0f5d81b13718a866cb078bd8762ab80a41972663',
#   'psmathur/model_007'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/upstage/llama-65b-instruct" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">upstage/llama-65b-instruct</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_upstage__llama-65b-instruct" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   63.1,
#   68.86,
#   86.43,
#   64.77,
#   59.7,
#   81.06,
#   26.23,
#   54.69,
#   'fine-tuned',
#   'torch.float16',
#   '?',
#   65.02,
#   9.0,
#   True,
#   'b95668861dfb7b0abca44ccdbef2db49b2dd8917',
#   'upstage/llama-65b-instruct'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/sequelbox/SharpBalance" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">sequelbox/SharpBalance</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_sequelbox__SharpBalance" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   63.01,
#   69.28,
#   87.59,
#   69.51,
#   59.05,
#   84.06,
#   34.65,
#   36.93,
#   'fine-tuned',
#   'torch.float16',
#   'llama2',
#   69.24,
#   3.0,
#   True,
#   'a87cb1756d7b7389cc5a6d4647cf53377e962aea',
#   'sequelbox/SharpBalance'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/migtissera/Synthia-70B-v1.1" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">migtissera/Synthia-70B-v1.1</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_migtissera__Synthia-70B-v1.1" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   62.84,
#   70.05,
#   87.12,
#   70.34,
#   57.84,
#   83.66,
#   31.84,
#   39.02,
#   'fine-tuned',
#   'torch.float16',
#   'llama2',
#   68.72,
#   7.0,
#   True,
#   '05a13f6adfe95a713dff04dc2eaa214c77c2512a',
#   'migtissera/Synthia-70B-v1.1'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/uni-tianyan/Uni-TianYan" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">uni-tianyan/Uni-TianYan</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_uni-tianyan__Uni-TianYan" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   62.78,
#   72.1,
#   87.4,
#   69.91,
#   65.81,
#   82.32,
#   22.14,
#   39.79,
#   'fine-tuned',
#   'torch.float16',
#   'llama2',
#   68.72,
#   48.0,
#   True,
#   '46b78b9a10e78283e59c28b56cb59c2f33b0816a',
#   'uni-tianyan/Uni-TianYan'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/OpenBuddy/openbuddy-llama-65b-v8-bf16" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">OpenBuddy/openbuddy-llama-65b-v8-bf16</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_OpenBuddy__openbuddy-llama-65b-v8-bf16" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   62.62,
#   62.8,
#   83.6,
#   62.01,
#   55.09,
#   79.95,
#   43.37,
#   51.5,
#   'fine-tuned',
#   'torch.bfloat16',
#   '?',
#   65.07,
#   8.0,
#   True,
#   '445b77821fac8e6cfb77d0399fb827400b5bb71e',
#   'OpenBuddy/openbuddy-llama-65b-v8-bf16'],
#  ['🟢',
#   '<a target="_blank" href="https://huggingface.co/TigerResearch/tigerbot-70b-base" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">TigerResearch/tigerbot-70b-base</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_TigerResearch__tigerbot-70b-base" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   62.1,
#   62.46,
#   83.61,
#   65.49,
#   52.76,
#   80.19,
#   37.76,
#   52.45,
#   'pretrained',
#   'torch.float16',
#   'apache-2.0',
#   68.95,
#   11.0,
#   True,
#   '8af85526293eb8625375f3f7a1bab69825176e48',
#   'TigerResearch/tigerbot-70b-base'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/psmathur/model_007_v2" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">psmathur/model_007_v2</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_psmathur__model_007_v2" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   62.02,
#   71.42,
#   87.31,
#   68.58,
#   62.65,
#   84.14,
#   28.66,
#   31.38,
#   'fine-tuned',
#   'torch.float16',
#   'llama2',
#   68.72,
#   1.0,
#   True,
#   '3d95e0f3598f7a76ab97cb2cc0e4aae957d77479',
#   'psmathur/model_007_v2'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/TheBloke/Airoboros-L2-70B-2.1-GPTQ" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">TheBloke/Airoboros-L2-70B-2.1-GPTQ</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_TheBloke__Airoboros-L2-70B-2.1-GPTQ" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   61.76,
#   70.39,
#   86.54,
#   68.89,
#   55.55,
#   81.61,
#   15.24,
#   54.1,
#   'fine-tuned',
#   'GPTQ',
#   'llama2',
#   72.82,
#   14.0,
#   True,
#   '23ed580cb77ebaee49ea11eb4538fd3ab3795b76',
#   'TheBloke/Airoboros-L2-70B-2.1-GPTQ'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/luffycodes/higgs-llama-vicuna-ep25-70b" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">luffycodes/higgs-llama-vicuna-ep25-70b</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_luffycodes__higgs-llama-vicuna-ep25-70b" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   61.54,
#   62.29,
#   86.07,
#   64.25,
#   53.75,
#   80.66,
#   34.57,
#   49.21,
#   'fine-tuned',
#   'torch.bfloat16',
#   'llama2',
#   68.72,
#   1.0,
#   True,
#   '1da59e150f1d0bae67f66400738a01d408a8c45d',
#   'luffycodes/higgs-llama-vicuna-ep25-70b'],
#  ['⭕',
#   '<a target="_blank" href="https://huggingface.co/chargoddard/MelangeC-70b" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">chargoddard/MelangeC-70b</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_chargoddard__MelangeC-70b" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   61.22,
#   71.67,
#   87.6,
#   70.37,
#   58.13,
#   83.98,
#   0.0,
#   56.81,
#   'instruction-tuned',
#   'torch.float16',
#   '?',
#   68.98,
#   0.0,
#   True,
#   'e54a2b924dec135f3fa2373933ab8485178cde1b',
#   'chargoddard/MelangeC-70b'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/Brillibits/Instruct_Llama70B_Dolly15k" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">Brillibits/Instruct_Llama70B_Dolly15k</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_Brillibits__Instruct_Llama70B_Dolly15k" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   60.97,
#   68.34,
#   87.21,
#   69.52,
#   46.46,
#   84.29,
#   42.68,
#   28.26,
#   'fine-tuned',
#   'torch.bfloat16',
#   'llama2',
#   68.72,
#   0.0,
#   True,
#   '45444ac60488594e0700e6c7313ff444b4468240',
#   'Brillibits/Instruct_Llama70B_Dolly15k'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/jondurbin/airoboros-l2-70b-gpt4-2.0" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">jondurbin/airoboros-l2-70b-gpt4-2.0</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_jondurbin__airoboros-l2-70b-gpt4-2.0" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   60.78,
#   68.52,
#   87.89,
#   70.41,
#   49.79,
#   83.5,
#   24.72,
#   40.63,
#   'fine-tuned',
#   'torch.float16',
#   'other',
#   68.72,
#   12.0,
#   True,
#   'f16526d9bb814dc10adc911f94e8c7a520beb5b6',
#   'jondurbin/airoboros-l2-70b-gpt4-2.0'],
#  ['⭕',
#   '<a target="_blank" href="https://huggingface.co/elinas/chronos007-70b" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">elinas/chronos007-70b</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_elinas__chronos007-70b" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   60.72,
#   70.14,
#   87.52,
#   69.33,
#   57.65,
#   82.24,
#   42.61,
#   15.52,
#   'instruction-tuned',
#   'torch.bfloat16',
#   'cc-by-nc-4.0',
#   68.98,
#   2.0,
#   True,
#   'c775f87a56f00725de4263f8d527995d40f611c4',
#   'elinas/chronos007-70b'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/OpenBuddy/openbuddy-falcon-180b-v12-preview0" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">OpenBuddy/openbuddy-falcon-180b-v12-preview0</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_OpenBuddy__openbuddy-falcon-180b-v12-preview0" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   60.54,
#   62.29,
#   83.8,
#   55.92,
#   53.05,
#   82.08,
#   41.24,
#   45.41,
#   'fine-tuned',
#   '4bit',
#   '?',
#   178.64,
#   0.0,
#   True,
#   '4f1aeb136860ee3216f23faec0c598014e5c40a6',
#   'OpenBuddy/openbuddy-falcon-180b-v12-preview0'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/Faradaylab/ARIA-70B-V3" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">Faradaylab/ARIA-70B-V3</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_Faradaylab__ARIA-70B-V3" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   60.53,
#   63.91,
#   86.21,
#   64.75,
#   51.32,
#   82.08,
#   28.13,
#   47.29,
#   'fine-tuned',
#   'torch.float16',
#   'other',
#   68.98,
#   0.0,
#   True,
#   '6e7fdcd20626786dd744ea86c664a3c088ced39f',
#   'Faradaylab/ARIA-70B-V3'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/migtissera/Synthia-70B" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">migtissera/Synthia-70B</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_migtissera__Synthia-70B" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   60.29,
#   69.45,
#   87.11,
#   68.91,
#   59.79,
#   83.66,
#   31.39,
#   21.75,
#   'fine-tuned',
#   'torch.float16',
#   'llama2',
#   68.72,
#   8.0,
#   True,
#   'd63dfdd0baed756981f5f78f7419fd822c572362',
#   'migtissera/Synthia-70B'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/llm-agents/tora-70b-v1.0" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">llm-agents/tora-70b-v1.0</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_llm-agents__tora-70b-v1.0" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   60.12,
#   67.75,
#   85.83,
#   69.22,
#   51.79,
#   81.93,
#   23.81,
#   40.52,
#   'fine-tuned',
#   'torch.float16',
#   'llama2',
#   68.72,
#   8.0,
#   True,
#   'e95fd7daf017e7c414ec07ebef4ddf013c16f9a4',
#   'llm-agents/tora-70b-v1.0'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/jondurbin/airoboros-l2-70b-gpt4-2.0" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">jondurbin/airoboros-l2-70b-gpt4-2.0</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_jondurbin__airoboros-l2-70b-gpt4-2.0" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   60.05,
#   68.6,
#   87.53,
#   69.37,
#   48.52,
#   83.9,
#   17.66,
#   44.74,
#   'fine-tuned',
#   '4bit',
#   'other',
#   68.72,
#   12.0,
#   True,
#   'f16526d9bb814dc10adc911f94e8c7a520beb5b6',
#   'jondurbin/airoboros-l2-70b-gpt4-2.0'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/oh-yeontaek/llama-2-70B-LoRA-assemble-v2" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">oh-yeontaek/llama-2-70B-LoRA-assemble-v2</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_oh-yeontaek__llama-2-70B-LoRA-assemble-v2" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   59.93,
#   71.84,
#   86.89,
#   69.37,
#   64.79,
#   81.22,
#   14.25,
#   31.14,
#   'fine-tuned',
#   'torch.float16',
#   '?',
#   68.72,
#   2.0,
#   True,
#   '7feeb5b665ab1ecdfd9cc4fe45fadb86b7b91b5b',
#   'oh-yeontaek/llama-2-70B-LoRA-assemble-v2'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/psmathur/test_42_70b" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">psmathur/test_42_70b</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_psmathur__test_42_70b" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   59.77,
#   68.26,
#   87.65,
#   70.0,
#   48.76,
#   83.66,
#   45.94,
#   14.09,
#   'fine-tuned',
#   'torch.float16',
#   '?',
#   68.72,
#   4.0,
#   True,
#   'ca3789cd6b683e97dcd6a5f0367f90a63d7a4e7b',
#   'psmathur/test_42_70b'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/meta-math/MetaMath-70B-V1.0" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">meta-math/MetaMath-70B-V1.0</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_meta-math__MetaMath-70B-V1.0" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   59.35,
#   68.0,
#   86.85,
#   69.31,
#   50.98,
#   82.32,
#   44.66,
#   13.37,
#   'fine-tuned',
#   'torch.float16',
#   'llama2',
#   68.72,
#   8.0,
#   True,
#   '783a3c7d5d0a75e6e11074f2577b90dd219ef7b1',
#   'meta-math/MetaMath-70B-V1.0'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/HiTZ/alpaca-lora-65b-en-pt-es-ca" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">HiTZ/alpaca-lora-65b-en-pt-es-ca</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_HiTZ__alpaca-lora-65b-en-pt-es-ca" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   59.31,
#   65.02,
#   84.88,
#   62.19,
#   46.06,
#   80.51,
#   26.69,
#   49.84,
#   'fine-tuned',
#   'torch.float16',
#   '?',
#   65.0,
#   2.0,
#   False,
#   'aa5bd88bd132925cf2dd5c44eceafdb5ed5e5be4',
#   'HiTZ/alpaca-lora-65b-en-pt-es-ca'],
#  ['🟢',
#   '<a target="_blank" href="https://huggingface.co/tiiuae/falcon-180B" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">tiiuae/falcon-180B</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_tiiuae__falcon-180B" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   59.1,
#   69.45,
#   88.86,
#   70.5,
#   45.47,
#   86.9,
#   45.94,
#   6.57,
#   'pretrained',
#   '8bit',
#   'unknown',
#   179.52,
#   830.0,
#   False,
#   '71a1a70b629e9963f7b4601e82f3f9079d48011e',
#   'tiiuae/falcon-180B'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/jondurbin/airoboros-l2-70b-gpt4-m2.0" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">jondurbin/airoboros-l2-70b-gpt4-m2.0</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_jondurbin__airoboros-l2-70b-gpt4-m2.0" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   59.08,
#   70.05,
#   87.83,
#   70.67,
#   49.79,
#   83.58,
#   25.4,
#   26.2,
#   'fine-tuned',
#   'torch.float16',
#   'other',
#   68.72,
#   10.0,
#   True,
#   '1cccd0b60a988bf6ddc4e2688895837845afa076',
#   'jondurbin/airoboros-l2-70b-gpt4-m2.0'],
#  ['?',
#   '<a target="_blank" href="https://huggingface.co/lizpreciatior/lzlv_70b_fp16_hf" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">lizpreciatior/lzlv_70b_fp16_hf</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_lizpreciatior__lzlv_70b_fp16_hf" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   59.06,
#   70.14,
#   87.54,
#   70.23,
#   60.49,
#   83.43,
#   30.93,
#   10.68,
#   '',
#   'torch.float16',
#   '?',
#   0.0,
#   0.0,
#   True,
#   'b366c0bb318ae592023cca894cc6b4421a607a0d',
#   'lizpreciatior/lzlv_70b_fp16_hf'],
#  ['?',
#   '<a target="_blank" href="https://huggingface.co/openbmb/UltraLM-65b" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">openbmb/UltraLM-65b</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_openbmb__UltraLM-65b" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   58.99,
#   67.06,
#   84.98,
#   63.48,
#   53.51,
#   81.14,
#   32.75,
#   30.0,
#   '',
#   'torch.float16',
#   '?',
#   65.02,
#   6.0,
#   False,
#   '',
#   'openbmb/UltraLM-65b'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/OpenBuddyEA/openbuddy-llama-30b-v7.1-bf16" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">OpenBuddyEA/openbuddy-llama-30b-v7.1-bf16</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_OpenBuddyEA__openbuddy-llama-30b-v7.1-bf16" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   58.89,
#   62.37,
#   82.29,
#   58.18,
#   52.6,
#   77.51,
#   31.61,
#   47.63,
#   'fine-tuned',
#   'torch.float16',
#   '?',
#   32.35,
#   6.0,
#   True,
#   '85f7ad9d6ff016312262a47d45ffd07dee54aab0',
#   'OpenBuddyEA/openbuddy-llama-30b-v7.1-bf16'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/Xwin-LM/Xwin-LM-70B-V0.1" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">Xwin-LM/Xwin-LM-70B-V0.1</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_Xwin-LM__Xwin-LM-70B-V0.1" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   58.87,
#   70.22,
#   87.25,
#   69.77,
#   59.86,
#   82.87,
#   27.22,
#   14.91,
#   'fine-tuned',
#   'torch.float16',
#   'llama2',
#   68.72,
#   159.0,
#   True,
#   'd6c803a180e3d46c371f8d3cb3848b861596ccbc',
#   'Xwin-LM/Xwin-LM-70B-V0.1'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/lilloukas/GPlatty-30B" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">lilloukas/GPlatty-30B</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_lilloukas__GPlatty-30B" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   58.87,
#   65.78,
#   84.79,
#   63.49,
#   52.45,
#   80.98,
#   13.87,
#   50.73,
#   'fine-tuned',
#   'torch.float16',
#   'other',
#   32.32,
#   18.0,
#   True,
#   '836cf4dcd60ebe2ff09415c72f809d94639e8d35',
#   'lilloukas/GPlatty-30B'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/ICBU-NPU/FashionGPT-70B-V1" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">ICBU-NPU/FashionGPT-70B-V1</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_ICBU-NPU__FashionGPT-70B-V1" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   58.85,
#   71.08,
#   87.32,
#   70.7,
#   63.92,
#   83.66,
#   28.13,
#   7.13,
#   'fine-tuned',
#   'torch.float16',
#   'llama2',
#   68.72,
#   4.0,
#   True,
#   '060c096af49700760f734c0102250a524d46b3eb',
#   'ICBU-NPU/FashionGPT-70B-V1'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/ICBU-NPU/FashionGPT-70B-V1.2" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">ICBU-NPU/FashionGPT-70B-V1.2</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_ICBU-NPU__FashionGPT-70B-V1.2" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   58.85,
#   73.04,
#   88.15,
#   70.11,
#   65.15,
#   82.56,
#   24.03,
#   8.9,
#   'fine-tuned',
#   'torch.float16',
#   'llama2',
#   68.72,
#   2.0,
#   True,
#   '990a1664fc058de6ee2406af62c0a817d7047304',
#   'ICBU-NPU/FashionGPT-70B-V1.2'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/OpenBuddyEA/openbuddy-llama-30b-v7.1-bf16" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">OpenBuddyEA/openbuddy-llama-30b-v7.1-bf16</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_OpenBuddyEA__openbuddy-llama-30b-v7.1-bf16" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   58.83,
#   62.46,
#   82.3,
#   58.15,
#   52.57,
#   77.82,
#   30.93,
#   47.55,
#   'fine-tuned',
#   'torch.bfloat16',
#   '?',
#   32.35,
#   6.0,
#   True,
#   '85f7ad9d6ff016312262a47d45ffd07dee54aab0',
#   'OpenBuddyEA/openbuddy-llama-30b-v7.1-bf16'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/jondurbin/airoboros-65b-gpt4-1.3" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">jondurbin/airoboros-65b-gpt4-1.3</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_jondurbin__airoboros-65b-gpt4-1.3" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   58.57,
#   66.13,
#   85.99,
#   63.89,
#   51.32,
#   79.95,
#   13.65,
#   49.07,
#   'fine-tuned',
#   'torch.float16',
#   'cc-by-nc-4.0',
#   65.02,
#   1.0,
#   True,
#   '4373e66135c6fb4a6063777c4270a34509e7e932',
#   'jondurbin/airoboros-65b-gpt4-1.3'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/upstage/llama-30b-instruct-2048" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">upstage/llama-30b-instruct-2048</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_upstage__llama-30b-instruct-2048" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   58.56,
#   64.93,
#   84.94,
#   61.9,
#   56.3,
#   79.56,
#   17.82,
#   44.46,
#   'fine-tuned',
#   'torch.float16',
#   '?',
#   32.32,
#   102.0,
#   True,
#   'be44a37814a20e790063086703f570732597887a',
#   'upstage/llama-30b-instruct-2048'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/jarradh/llama2_70b_chat_uncensored" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">jarradh/llama2_70b_chat_uncensored</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_jarradh__llama2_70b_chat_uncensored" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   58.48,
#   68.43,
#   86.77,
#   68.76,
#   52.5,
#   82.56,
#   30.25,
#   20.09,
#   'fine-tuned',
#   'torch.float16',
#   'llama2',
#   68.72,
#   37.0,
#   True,
#   '34b23982a9a996adc8f45c4c2eac7245c4e251b3',
#   'jarradh/llama2_70b_chat_uncensored'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/Doctor-Shotgun/mythospice-limarp-70b" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">Doctor-Shotgun/mythospice-limarp-70b</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_Doctor-Shotgun__mythospice-limarp-70b" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   58.45,
#   69.2,
#   87.46,
#   70.14,
#   55.86,
#   82.72,
#   32.22,
#   11.59,
#   'fine-tuned',
#   'torch.float16',
#   'agpl-3.0',
#   68.72,
#   0.0,
#   True,
#   'ff29fed2a33fc050fd20d0e25b5b23c4a101b074',
#   'Doctor-Shotgun/mythospice-limarp-70b'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/psmathur/model_420" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">psmathur/model_420</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_psmathur__model_420" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   58.41,
#   70.14,
#   87.73,
#   70.35,
#   54.0,
#   83.74,
#   28.58,
#   14.35,
#   'fine-tuned',
#   'torch.float16',
#   '?',
#   68.72,
#   1.0,
#   True,
#   '13c7b5f403c0f2af9bf7fce2d4a32deb9054c083',
#   'psmathur/model_420'],
#  ['🔶',
# ...
#   42.57,
#   48.04,
#   76.28,
#   47.42,
#   44.4,
#   70.09,
#   6.22,
#   5.57,
#   'fine-tuned',
#   'torch.float16',
#   'other',
#   6.61,
#   0.0,
#   True,
#   'e4b19d9d6168b32402da4ab2b5ec7ff27cf40d9b',
#   'Aspik101/vicuna-7b-v1.3-instruct-pl-lora_unload'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/speechlessai/speechless-codellama-airoboros-orca-platypus-13b" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">speechlessai/speechless-codellama-airoboros-orca-platypus-13b</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_speechlessai__speechless-codellama-airoboros-orca-platypus-13b" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   42.55,
#   44.88,
#   67.7,
#   43.16,
#   40.88,
#   66.14,
#   1.82,
#   33.26,
#   'fine-tuned',
#   'torch.bfloat16',
#   'llama2',
#   12.85,
#   0.0,
#   True,
#   'f01d3ab70cc23e31dcf5d6418406b08dc2003153',
#   'speechlessai/speechless-codellama-airoboros-orca-platypus-13b'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/Charlie911/vicuna-7b-v1.5-lora-mctaco-modified4" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">Charlie911/vicuna-7b-v1.5-lora-mctaco-modified4</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_Charlie911__vicuna-7b-v1.5-lora-mctaco-modified4" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   42.54,
#   40.7,
#   73.08,
#   47.26,
#   41.59,
#   67.88,
#   0.08,
#   27.17,
#   'fine-tuned',
#   'torch.float16',
#   '?',
#   6.61,
#   0.0,
#   True,
#   '715b03c8573df06f3825d1c08b307e2a83fa8bf9',
#   'Charlie911/vicuna-7b-v1.5-lora-mctaco-modified4'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/elyza/ELYZA-japanese-Llama-2-7b" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">elyza/ELYZA-japanese-Llama-2-7b</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_elyza__ELYZA-japanese-Llama-2-7b" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   42.53,
#   52.22,
#   76.42,
#   44.6,
#   37.92,
#   72.69,
#   8.34,
#   5.53,
#   'fine-tuned',
#   'torch.float16',
#   'llama2',
#   6.61,
#   32.0,
#   True,
#   '976887c5891284db204320860bb84b71d598063e',
#   'elyza/ELYZA-japanese-Llama-2-7b'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/TheTravellingEngineer/llama2-7b-chat-hf-v3" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">TheTravellingEngineer/llama2-7b-chat-hf-v3</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_TheTravellingEngineer__llama2-7b-chat-hf-v3" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   42.51,
#   51.96,
#   76.7,
#   45.36,
#   38.31,
#   73.56,
#   5.99,
#   5.7,
#   'fine-tuned',
#   'torch.bfloat16',
#   '?',
#   6.74,
#   0.0,
#   True,
#   'a5269bc93a7f98e192e34553cec1302877ca4327',
#   'TheTravellingEngineer/llama2-7b-chat-hf-v3'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/PocketDoc/Dans-CreepingSenseOfDoom" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">PocketDoc/Dans-CreepingSenseOfDoom</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_PocketDoc__Dans-CreepingSenseOfDoom" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   42.48,
#   53.33,
#   78.9,
#   48.09,
#   37.84,
#   73.32,
#   0.0,
#   5.9,
#   'fine-tuned',
#   'torch.float16',
#   '?',
#   12.85,
#   3.0,
#   True,
#   'efc7cbc5d0461c137e8ea0c83e54bc5357188783',
#   'PocketDoc/Dans-CreepingSenseOfDoom'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/shibing624/chinese-alpaca-plus-7b-hf" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">shibing624/chinese-alpaca-plus-7b-hf</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_shibing624__chinese-alpaca-plus-7b-hf" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   42.46,
#   49.23,
#   70.48,
#   38.39,
#   39.72,
#   70.09,
#   0.68,
#   28.61,
#   'fine-tuned',
#   'torch.float16',
#   'other',
#   6.68,
#   46.0,
#   True,
#   '0deb5a13732f1e3e3240ea83f403c57283fe2dc8',
#   'shibing624/chinese-alpaca-plus-7b-hf'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/Linly-AI/Chinese-LLaMA-2-7B-hf" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">Linly-AI/Chinese-LLaMA-2-7B-hf</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_Linly-AI__Chinese-LLaMA-2-7B-hf" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   42.44,
#   48.04,
#   73.25,
#   35.04,
#   39.92,
#   70.17,
#   6.22,
#   24.46,
#   'fine-tuned',
#   'torch.float16',
#   '?',
#   6.64,
#   15.0,
#   True,
#   'a2d55220b3d0693825fe69e1174653dc6cc4a920',
#   'Linly-AI/Chinese-LLaMA-2-7B-hf'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/FelixChao/vicuna-7B-chemical" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">FelixChao/vicuna-7B-chemical</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_FelixChao__vicuna-7B-chemical" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   42.4,
#   49.83,
#   74.42,
#   44.1,
#   51.7,
#   67.17,
#   3.34,
#   6.26,
#   'fine-tuned',
#   'torch.bfloat16',
#   'apache-2.0',
#   6.61,
#   0.0,
#   True,
#   'fbf6476ebfa856ffe743e41f8d4413c15b2127c9',
#   'FelixChao/vicuna-7B-chemical'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/jphme/orca_mini_v2_ger_7b" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">jphme/orca_mini_v2_ger_7b</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_jphme__orca_mini_v2_ger_7b" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   42.33,
#   49.83,
#   75.5,
#   39.1,
#   45.74,
#   71.59,
#   4.17,
#   10.42,
#   'fine-tuned',
#   'torch.float16',
#   'cc-by-nc-sa-4.0',
#   6.61,
#   8.0,
#   True,
#   '175965f50907c6a8cd40f1a4b10d28342969c066',
#   'jphme/orca_mini_v2_ger_7b'],
#  ['🟢',
#   '<a target="_blank" href="https://huggingface.co/TheBloke/Llama-2-7B-GPTQ" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">TheBloke/Llama-2-7B-GPTQ</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_TheBloke__Llama-2-7B-GPTQ" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   42.33,
#   52.05,
#   77.59,
#   43.99,
#   39.32,
#   72.93,
#   5.0,
#   5.45,
#   'pretrained',
#   'GPTQ',
#   'llama2',
#   9.05,
#   58.0,
#   True,
#   'ecd7ab9f6adc36ecbe0d751eeea0d90ae1863c3b',
#   'TheBloke/Llama-2-7B-GPTQ'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/LLMs/AlpacaGPT4-7B-elina" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">LLMs/AlpacaGPT4-7B-elina</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_LLMs__AlpacaGPT4-7B-elina" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   42.3,
#   55.03,
#   78.79,
#   37.5,
#   41.53,
#   72.69,
#   4.55,
#   6.02,
#   'fine-tuned',
#   'torch.float16',
#   '?',
#   6.61,
#   5.0,
#   True,
#   'bbece5e3f8ee9be09c8defc536a95c6ef780c681',
#   'LLMs/AlpacaGPT4-7B-elina'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/jondurbin/airoboros-7b-gpt4-1.3" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">jondurbin/airoboros-7b-gpt4-1.3</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_jondurbin__airoboros-7b-gpt4-1.3" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   42.3,
#   52.47,
#   77.98,
#   41.97,
#   35.73,
#   72.3,
#   0.99,
#   14.64,
#   'fine-tuned',
#   'torch.float16',
#   'cc-by-nc-4.0',
#   6.61,
#   0.0,
#   True,
#   '7b5f77827636bbf3174c48ca16e774c89d71d7bd',
#   'jondurbin/airoboros-7b-gpt4-1.3'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/Juniplayground/Mist_LLaMA-2-7B-1024_V3" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">Juniplayground/Mist_LLaMA-2-7B-1024_V3</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_Juniplayground__Mist_LLaMA-2-7B-1024_V3" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   42.2,
#   51.37,
#   77.74,
#   41.34,
#   41.21,
#   73.32,
#   4.85,
#   5.57,
#   'fine-tuned',
#   'torch.float16',
#   '?',
#   6.61,
#   0.0,
#   True,
#   '05ec8f4a568777e1e543acdf8a587e080fb18fba',
#   'Juniplayground/Mist_LLaMA-2-7B-1024_V3'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/jondurbin/airoboros-gpt-3.5-turbo-100k-7b" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">jondurbin/airoboros-gpt-3.5-turbo-100k-7b</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_jondurbin__airoboros-gpt-3.5-turbo-100k-7b" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   42.13,
#   53.07,
#   76.16,
#   33.63,
#   45.07,
#   70.8,
#   3.56,
#   12.63,
#   'fine-tuned',
#   'torch.float16',
#   'cc-by-nc-4.0',
#   6.61,
#   11.0,
#   True,
#   '53887996c0f17f7711d182537505a895fb404542',
#   'jondurbin/airoboros-gpt-3.5-turbo-100k-7b'],
#  ['⭕',
#   '<a target="_blank" href="https://huggingface.co/LLMs/Stable-Vicuna-13B" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">LLMs/Stable-Vicuna-13B</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_LLMs__Stable-Vicuna-13B" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   42.09,
#   53.41,
#   78.57,
#   50.37,
#   48.36,
#   56.99,
#   0.0,
#   6.94,
#   'instruction-tuned',
#   'torch.float16',
#   'gpl-3.0',
#   12.85,
#   5.0,
#   True,
#   '51f3d9eaa71de287c96195abd0ff954839857b19',
#   'LLMs/Stable-Vicuna-13B'],
#  ['⭕',
#   '<a target="_blank" href="https://huggingface.co/openthaigpt/openthaigpt-1.0.0-alpha-7b-chat-ckpt-hf" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">openthaigpt/openthaigpt-1.0.0-alpha-7b-chat-ckpt-hf</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_openthaigpt__openthaigpt-1.0.0-alpha-7b-chat-ckpt-hf" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   42.05,
#   50.85,
#   74.89,
#   40.02,
#   47.23,
#   69.06,
#   3.87,
#   8.42,
#   'instruction-tuned',
#   'torch.float16',
#   'apache-2.0',
#   6.61,
#   1.0,
#   True,
#   'cdffb3488c5cb1a9aa5039a6b3bc72af24827db0',
#   'openthaigpt/openthaigpt-1.0.0-alpha-7b-chat-ckpt-hf'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/mosaicml/mpt-7b-8k-instruct" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">mosaicml/mpt-7b-8k-instruct</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_mosaicml__mpt-7b-8k-instruct" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   42.01,
#   45.9,
#   74.43,
#   42.09,
#   35.13,
#   65.9,
#   10.08,
#   20.54,
#   'fine-tuned',
#   'torch.float16',
#   'cc-by-sa-3.0',
#   6.65,
#   23.0,
#   True,
#   '736f68aceeb61298a5de3cf5ae81d0bc2697edf4',
#   'mosaicml/mpt-7b-8k-instruct'],
#  ['?',
#   '<a target="_blank" href="https://huggingface.co/TigerResearch/tigerbot-7b-base" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">TigerResearch/tigerbot-7b-base</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_TigerResearch__tigerbot-7b-base" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   41.99,
#   47.7,
#   72.08,
#   45.11,
#   42.27,
#   69.61,
#   10.84,
#   6.3,
#   '',
#   'torch.float16',
#   'apache-2.0',
#   6.73,
#   0.0,
#   True,
#   '300831494aa1eb16e59799310a09531f60dcc904',
#   'TigerResearch/tigerbot-7b-base'],
#  ['?',
#   '<a target="_blank" href="https://huggingface.co/chavinlo/alpaca-native" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">chavinlo/alpaca-native</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_chavinlo__alpaca-native" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   41.96,
#   52.3,
#   77.09,
#   41.6,
#   37.58,
#   69.46,
#   1.44,
#   14.23,
#   '',
#   'torch.float16',
#   '?',
#   6.61,
#   249.0,
#   True,
#   'cc7773cac2478231807c56ef2f02292d98f85cf5',
#   'chavinlo/alpaca-native'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/jerryjalapeno/nart-100k-7b" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">jerryjalapeno/nart-100k-7b</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_jerryjalapeno__nart-100k-7b" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   41.91,
#   54.1,
#   78.47,
#   34.98,
#   36.74,
#   70.48,
#   3.56,
#   15.02,
#   'fine-tuned',
#   'torch.float16',
#   'cc-by-nc-nd-4.0',
#   6.61,
#   13.0,
#   True,
#   '50e61b8e6cc17cb3fbcb490fe3dc7e2c8b248378',
#   'jerryjalapeno/nart-100k-7b'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/ehartford/WizardLM-7B-Uncensored" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">ehartford/WizardLM-7B-Uncensored</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_ehartford__WizardLM-7B-Uncensored" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   41.9,
#   47.87,
#   73.08,
#   35.42,
#   41.49,
#   68.43,
#   3.26,
#   23.76,
#   'fine-tuned',
#   'torch.float16',
#   'other',
#   6.61,
#   339.0,
#   True,
#   '14c23f9fa775ab5ce49010418f00df06d92b0b13',
#   'ehartford/WizardLM-7B-Uncensored'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/ehartford/dolphin-llama2-7b" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">ehartford/dolphin-llama2-7b</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_ehartford__dolphin-llama2-7b" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   41.88,
#   46.59,
#   67.52,
#   48.37,
#   49.72,
#   63.77,
#   5.69,
#   11.53,
#   'fine-tuned',
#   'torch.float16',
#   'llama2',
#   6.61,
#   64.0,
#   True,
#   '85aa4f67191fd016ab7ea8c389fddb5d9e5a9a52',
#   'ehartford/dolphin-llama2-7b'],
#  ['🔶',
#   '<a target="_blank" href="https://huggingface.co/DevaMalla/llama_7b_qlora_pds-eval" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">DevaMalla/llama_7b_qlora_pds-eval</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_DevaMalla__llama_7b_qlora_pds-eval" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>',
#   41.87,
#   53.92,
#   78.13,
#   32.98,
#   45.6,
#   72.61,
#   4.17,
#   5.66,
#   'fine-tuned',
#   'torch.bfloat16',
#   '?',
#   7.0,
#   0.0,
#   False,
#   'd20419e1d9e9a6a59ced3edf5169e8e7b3e8394c',
#   'DevaMalla/llama_7b_qlora_pds-eval'],
#  ...]

# %%
for idx, model in enumerate(data):
    if model[-1] == "tiiuae/falcon-180B":
        print(model)
# Out:
# ['🟢', '<a target="_blank" href="https://huggingface.co/tiiuae/falcon-180B" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">tiiuae/falcon-180B</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_tiiuae__falcon-180B" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>', 59.1, 69.45, 88.86, 70.5, 45.47, 86.9, 45.94, 6.57, 'pretrained', '8bit', 'unknown', 179.52, 830.0, False, '71a1a70b629e9963f7b4601e82f3f9079d48011e', 'tiiuae/falcon-180B']
# ['🟢', '<a target="_blank" href="https://huggingface.co/tiiuae/falcon-180B" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">tiiuae/falcon-180B</a>  <a target="_blank" href="https://huggingface.co/datasets/open-llm-leaderboard/details_tiiuae__falcon-180B" style="color: var(--link-text-color); text-decoration: underline;text-decoration-style: dotted;">📑</a>', 57.11, 69.2, 88.89, 69.59, 45.16, 86.74, 33.21, 7.02, 'pretrained', '4bit', 'unknown', 179.52, 830.0, False, '71a1a70b629e9963f7b4601e82f3f9079d48011e', 'tiiuae/falcon-180B']

# %%
# data segmentation according to types
grouped = data.groupby('Type')
dataframes = {name: group for name, group in grouped} # create seperate dfs for each type of models
print(dataframes.keys())

# four type of models
RL_tuned_models = dataframes['RL-tuned']
fine_tuned_models = dataframes['fine-tuned']
instruction_tuned_models = dataframes['instruction-tuned']
pretrained_models = dataframes['pretrained']

print(len(RL_tuned_models), len(fine_tuned_models), len(instruction_tuned_models), len(pretrained_models)) # number of models of each type
print(len(data)-sum([len(RL_tuned_models), len(fine_tuned_models), len(instruction_tuned_models), len(pretrained_models)])) # some models have NaN types, 120
modelsets = []
modelsets.extend([RL_tuned_models, fine_tuned_models, instruction_tuned_models, pretrained_models, data])
# Out:
# dict_keys(['RL-tuned', 'fine-tuned', 'instruction-tuned', 'pretrained'])
# 17 1200 282 204
# 120

# %%
# visualization func
def visual(models, name):
    # Extract the values from the second dimension
    sizes = models['#Params (B)'].values

    # Plot the histogram
    plt.hist(sizes, bins='auto')  # 'auto' will automatically determine the number of bins
    plt.xlabel('#Params (B)')
    plt.ylabel('Frequency')
    plt.title(f'{name}: Distribution of #Params (B)')
    plt.show()

# %%
# visualize the distribution of model sizes
modelset_names = ["RL_tuned_models", "fine_tuned_models", "instruction_tuned_models", "pretrained_models", "full"]
for i, models in enumerate(modelsets):
    visual(models, modelset_names[i])

# %%
seperation = [1, 1.5, 3, 7, 13, 35, 60, 70] # model size ranges
# finding best model within each size range
def find_best_model(models):
    best_model_names = set()
    for i in range(len(seperation)+1):
        low = seperation[i-1] if i != 0 else 0
        high = seperation[i] if i != len(seperation) else None
        sub_models = models[models['#Params (B)'] >= low]
        if high: sub_models = sub_models[sub_models['#Params (B)'] < high] # if high is not None
        if len(sub_models) == 0: continue # skip if there are no models within this size range
        max_score_index = sub_models['Average ⬆️'].idxmax()
        print(f'({low},{high})', sub_models.loc[max_score_index]["Model"])
        best_model_names.add(((low, high), sub_models.loc[max_score_index]["Model"]))
    return best_model_names

# %%
# finding and printing best models
best_models = []
for i, models in enumerate(modelsets):
    print(f'{modelset_names[i]}:')
    best_models.append(find_best_model(models))
# Out:
# RL_tuned_models:
# (0,1) Locutusque/gpt2-large-conversational
# (3,7) meta-llama/Llama-2-7b-chat-hf
# (7,13) xxyyy123/mc_data_30k_from_platpus_orca_7b_10k_v1_lora_qkvo_rank14_v2
# (13,35) Yhyu13/oasst-rlhf-2-llama-30b-7k-steps-hf
# (60,70) meta-llama/Llama-2-70b-chat-hf
# (70,None) tiiuae/falcon-180B-chat
# fine_tuned_models:
# (0,1) aisquared/dlite-v2-774m
# (1,1.5) AA051610/T1B
# (1.5,3) Fredithefish/RedPajama-INCITE-Chat-3B-Instruction-Tuning-with-GPT-4
# (3,7) oh-yeontaek/llama-2-7B-LoRA-assemble
# (7,13) Undi95/Mistral-11B-TestBench11
# (13,35) ajibawa-2023/scarlett-33b
# (35,60) dfurman/falcon-40b-openassistant-peft
# (60,70) ValiantLabs/ShiningValiant
# (70,None) adonlee/LLaMA_2_70B_LoRA
# instruction_tuned_models:
# (0,1) nicholasKluge/Aira-2-774M
# (1,1.5) lgaalves/tinyllama-1.1b-chat-v0.3_platypus
# (1.5,3) RWKV/rwkv-raven-3b
# (3,7) pankajmathur/orca_mini_v3_7b
# (7,13) ehartford/dolphin-2.1-mistral-7b
# (13,35) Weyaxi/Luban-Marcoroni-13B
# (60,70) budecosystem/genz-70b
# (70,None) TheBloke/Genz-70b-GPTQ
# pretrained_models:
# (0,1) KoboldAI/fairseq-dense-355M
# (1,1.5) microsoft/phi-1_5
# (1.5,3) stabilityai/stablelm-3b-4e1t
# (3,7) meta-llama/Llama-2-7b-hf
# (7,13) kittn/mistral-7B-v0.1-hf
# (13,35) internlm/internlm-20b
# (35,60) tiiuae/falcon-40b
# (60,70) meta-llama/Llama-2-70b-hf
# (70,None) tiiuae/falcon-180B
# full:
# (0,1) aisquared/dlite-v2-774m
# (1,1.5) AA051610/T1B
# (1.5,3) stabilityai/stablelm-3b-4e1t
# (3,7) oh-yeontaek/llama-2-7B-LoRA-assemble
# (7,13) Undi95/Mistral-11B-TestBench11
# (13,35) ehartford/samantha-1.1-llama-33b
# (35,60) dfurman/falcon-40b-openassistant-peft
# (60,70) ValiantLabs/ShiningValiant
# (70,None) adonlee/LLaMA_2_70B_LoRA

# %%
# create a set to filter out duplicates
models = set((*best_models[0], *best_models[1], *best_models[2], *best_models[3], *best_models[4]))
for model in sorted(models, key=lambda x: x[0][0]):
    print(model[0],model[1]) # print out sorted distinct model list
# Out:
# (0, 1) nicholasKluge/Aira-2-774M
# (0, 1) aisquared/dlite-v2-774m
# (0, 1) KoboldAI/fairseq-dense-355M
# (0, 1) Locutusque/gpt2-large-conversational
# (1, 1.5) lgaalves/tinyllama-1.1b-chat-v0.3_platypus
# (1, 1.5) AA051610/T1B
# (1, 1.5) microsoft/phi-1_5
# (1.5, 3) stabilityai/stablelm-3b-4e1t
# (1.5, 3) Fredithefish/RedPajama-INCITE-Chat-3B-Instruction-Tuning-with-GPT-4
# (1.5, 3) RWKV/rwkv-raven-3b
# (3, 7) meta-llama/Llama-2-7b-chat-hf
# (3, 7) oh-yeontaek/llama-2-7B-LoRA-assemble
# (3, 7) meta-llama/Llama-2-7b-hf
# (3, 7) pankajmathur/orca_mini_v3_7b
# (7, 13) ehartford/dolphin-2.1-mistral-7b
# (7, 13) kittn/mistral-7B-v0.1-hf
# (7, 13) Undi95/Mistral-11B-TestBench11
# (7, 13) xxyyy123/mc_data_30k_from_platpus_orca_7b_10k_v1_lora_qkvo_rank14_v2
# (13, 35) Yhyu13/oasst-rlhf-2-llama-30b-7k-steps-hf
# (13, 35) Weyaxi/Luban-Marcoroni-13B
# (13, 35) ajibawa-2023/scarlett-33b
# (13, 35) internlm/internlm-20b
# (13, 35) ehartford/samantha-1.1-llama-33b
# (35, 60) tiiuae/falcon-40b
# (35, 60) dfurman/falcon-40b-openassistant-peft
# (60, 70) ValiantLabs/ShiningValiant
# (60, 70) budecosystem/genz-70b
# (60, 70) meta-llama/Llama-2-70b-chat-hf
# (60, 70) meta-llama/Llama-2-70b-hf
# (70, None) adonlee/LLaMA_2_70B_LoRA
# (70, None) TheBloke/Genz-70b-GPTQ
# (70, None) tiiuae/falcon-180B
# (70, None) tiiuae/falcon-180B-chat
